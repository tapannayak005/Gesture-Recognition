# %% [markdown]
# # RNN - Gesture Recognition Case Study

# %% [markdown]
# ## Deep Learning Course Project - Gesture Recognition
#
# ### Problem Statement
# Imagine you are working as a data scientist at a home electronics company which manufactures state of the art smart televisions. You want to develop a cool feature in the smart-TV that can recognise five different gestures performed by the user which will help users control the TV without using a remote.
#
# The gestures are continuously monitored by the webcam mounted on the TV. Each gesture corresponds to a specific command:
#
# | Gesture | Corresponding Action |
# | --- | --- |
# | Thumbs Up | Increase the volume. |
# | Thumbs Down | Decrease the volume. |
# | Left Swipe | 'Jump' backwards 10 seconds. |
# | Right Swipe | 'Jump' forward 10 seconds. |
# | Stop | Pause the movie. |
#
# Each video is a sequence of 30 frames (or images).
#
# ### Objectives:
# 1. **Generator**:  The generator should be able to take a batch of videos as input without any error. Steps like cropping, resizing and normalization should be performed successfully.
#
# 2. **Model**: Develop a model that is able to train without any errors which will be judged on the total number of parameters (as the inference(prediction) time should be less) and the accuracy achieved. As suggested by Snehansu, start training on a small amount of data and then proceed further.
#
# 3. **Write up**: This should contain the detailed procedure followed in choosing the final model. The write up should start with the reason for choosing the base model, then highlight the reasons and metrics taken into consideration to modify and experiment to arrive at the final model.

# %%
import numpy as np

import os
import scipy
#!pip install imageio
#!pip install scikit-image
import imageio #Added this import
from imageio import imread # Changed this line from scipy.imageio to imageio
from skimage.transform import resize
import datetime
from skimage.transform import resize #Added this line to import the resize function from scikit-image
import datetime
import cv2
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
# Doing the required imports :
from tensorflow.keras.models import Sequential
from keras.models import Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers
from keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling3D, Conv3D, MaxPooling2D
from keras.layers import GRU
from keras.layers import Activation, Dropout, ZeroPadding3D
from keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
import tensorflow as tf
tf.random.set_seed(30)
from keras import backend as k
import abc

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
project_folder='datasets/Project_data'

# %% [markdown]
# ## Plotting

# %%
# function to plot the training/validation accuracies/losses.

def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].grid()
    axes[0].legend(['loss','val_loss'])
    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].grid()
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
class ModelBuilder(metaclass= abc.ABCMeta):
    # initialisng the path where project data resides
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
    # initialising the image properties    
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
    # initialising the batch size, frames to sample and the no. of epochs
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
    # MOST IMPORTANT PART HERE - The generator function        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx):
                #performing image reading and resizing
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=resize(image,(self.image_height,self.image_width,3))
            
                #normalizing the images
                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    # cropping the images to have the targeted gestures and remove the noise from the images.
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=resize(cropped,(self.image_height,self.image_width,3))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (image_resized[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        
        earlystop = EarlyStopping( monitor="val_loss", min_delta=0,patience=10,verbose=1)
        callbacks_list = [checkpoint, LR, earlystop]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, initial_epoch=0)
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %% [markdown]
# ## Sample Model

# %%
class ModelConv3D1(ModelBuilder):
    
    def define_model(self):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(128,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))

        model.add(Dense(64,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.25))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser=Adam()
        #optimiser = 'sgd'
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=10,num_epochs=1)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 160, 160, 16)  1312
#
#  activation (Activation)     (None, 30, 160, 160, 16)  0
#
#  batch_normalization (BatchN  (None, 30, 160, 160, 16)  64
#  ormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 15, 80, 80, 16)   0
#  )
#
#  conv3d_1 (Conv3D)           (None, 15, 80, 80, 32)    4128
#
#  activation_1 (Activation)   (None, 15, 80, 80, 32)    0
#
#  batch_normalization_1 (Batc  (None, 15, 80, 80, 32)   128
#  hNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 7, 40, 40, 32)    0
#  3D)
#
#  conv3d_2 (Conv3D)           (None, 7, 40, 40, 64)     16448
#
#  activation_2 (Activation)   (None, 7, 40, 40, 64)     0
#
#  batch_normalization_2 (Batc  (None, 7, 40, 40, 64)    256
#  hNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 3, 20, 20, 64)    0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 3, 20, 20, 128)    65664
#
#  activation_3 (Activation)   (None, 3, 20, 20, 128)    0
#
#  batch_normalization_3 (Batc  (None, 3, 20, 20, 128)   512
#  hNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 1, 10, 10, 128)   0
#  3D)
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 128)               1638528
#
#  batch_normalization_4 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 1,736,389
# Trainable params: 1,735,525
# Non-trainable params: 864
# _________________________________________________________________
# 2024-09-02 05:42:22.804841: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-09-02 05:42:22.804902: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14800 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:41:00.0, compute capability: 7.5

# %% [markdown]
# ##### Sample Cropping

# %%
test_generator=ModelConv3D1()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=160,image_width=160)
test_generator.initialize_hyperparams(frames_to_sample=30,batch_size=3,num_epochs=1)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=True)
batch_data, batch_labels=next(g)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,15,:,:,:])   
axes[1].imshow(batch_data[3,15,:,:,:])   
plt.show()

# %% [markdown]
# ## Experimenting with Image resolution, number of frames to use and batch_size

# %%
conv_3d1.train_model(conv_3d1_model)
# Out:
# 2024-09-01 11:09:52.695568: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 67/67 [==============================] - ETA: 0s - loss: 1.5389 - categorical_accuracy: 0.4359
# Epoch 00001: val_loss improved from inf to 3.32063, saving model to model_init_2024-09-0111_09_47.030169/model-00001-1.53885-0.43590-3.32063-0.16000.keras
# 67/67 [==============================] - 194s 3s/step - loss: 1.5389 - categorical_accuracy: 0.4359 - val_loss: 3.3206 - val_categorical_accuracy: 0.1600 - lr: 0.0010

# %% [markdown]
# ### So lets trade-off between these parameters

# %% [markdown]
# #### Below are the experiments to see how training time is affected by image resolution, number of images in sequence and batch size

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=100,image_width=100)
conv_3d1.initialize_hyperparams(frames_to_sample=20,batch_size=30,num_epochs=2)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 687813
# Epoch 1/2
# 23/23 [==============================] - ETA: 0s - loss: 1.7450 - categorical_accuracy: 0.3710
# Epoch 00001: val_loss improved from inf to 2.13502, saving model to model_init_2024-09-0111_13_04.809434/model-00001-1.74503-0.37104-2.13502-0.23000.keras
# 23/23 [==============================] - 104s 5s/step - loss: 1.7450 - categorical_accuracy: 0.3710 - val_loss: 2.1350 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 2/2
# 23/23 [==============================] - ETA: 0s - loss: 1.1620 - categorical_accuracy: 0.5611
# Epoch 00002: val_loss did not improve from 2.13502
# 23/23 [==============================] - 103s 5s/step - loss: 1.1620 - categorical_accuracy: 0.5611 - val_loss: 3.5454 - val_categorical_accuracy: 0.1500 - lr: 0.0010

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=100,image_width=100)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=20,num_epochs=2)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 687813
# Epoch 1/2
# 34/34 [==============================] - ETA: 0s - loss: 1.5074 - categorical_accuracy: 0.4268
# Epoch 00001: val_loss improved from inf to 2.28279, saving model to model_init_2024-09-0111_16_36.084970/model-00001-1.50740-0.42685-2.28279-0.16000.keras
# 34/34 [==============================] - 155s 5s/step - loss: 1.5074 - categorical_accuracy: 0.4268 - val_loss: 2.2828 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 2/2
# 34/34 [==============================] - ETA: 0s - loss: 1.0943 - categorical_accuracy: 0.5701
# Epoch 00002: val_loss did not improve from 2.28279
# 34/34 [==============================] - 152s 5s/step - loss: 1.0943 - categorical_accuracy: 0.5701 - val_loss: 3.2643 - val_categorical_accuracy: 0.2000 - lr: 0.0010

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=15,num_epochs=2)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1736389
# Epoch 1/2
# 45/45 [==============================] - ETA: 0s - loss: 1.6766 - categorical_accuracy: 0.3967
# Epoch 00001: val_loss improved from inf to 6.44625, saving model to model_init_2024-09-0111_21_46.757606/model-00001-1.67662-0.39668-6.44625-0.16000.keras
# 45/45 [==============================] - 173s 4s/step - loss: 1.6766 - categorical_accuracy: 0.3967 - val_loss: 6.4462 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 2/2
# 45/45 [==============================] - ETA: 0s - loss: 1.1296 - categorical_accuracy: 0.5641
# Epoch 00002: val_loss did not improve from 6.44625
# 45/45 [==============================] - 171s 4s/step - loss: 1.1296 - categorical_accuracy: 0.5641 - val_loss: 8.2621 - val_categorical_accuracy: 0.1700 - lr: 0.0010

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=2)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1736389
# Epoch 1/2
# 23/23 [==============================] - ETA: 0s - loss: 1.5465 - categorical_accuracy: 0.3922
# Epoch 00001: val_loss improved from inf to 3.53169, saving model to model_init_2024-09-0111_27_33.966069/model-00001-1.54648-0.39216-3.53169-0.16000.keras
# 23/23 [==============================] - 93s 4s/step - loss: 1.5465 - categorical_accuracy: 0.3922 - val_loss: 3.5317 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 2/2
# 23/23 [==============================] - ETA: 0s - loss: 1.0171 - categorical_accuracy: 0.5837
# Epoch 00002: val_loss did not improve from 3.53169
# 23/23 [==============================] - 91s 4s/step - loss: 1.0171 - categorical_accuracy: 0.5837 - val_loss: 6.6038 - val_categorical_accuracy: 0.1900 - lr: 0.0010

# %% [markdown]
# - As we see from the above experiments **"image resolution"** and **number of frames** in sequence have more impact on training time than **batch_size**
# - We can consider the Batch Size around 15-40
# - We will change the resoulution 160 * 160, 120 * 120 according the model performance

# %% [markdown]
# ## Model 1
# ### Base Model - Batch Size = 40 and No. of Epochs = 20

# %%
class ModelConv3D1(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser=Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=20,batch_size=40,num_epochs=20)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_32 (Conv3D)          (None, 20, 160, 160, 16)  1312
#
#  activation_32 (Activation)  (None, 20, 160, 160, 16)  0
#
#  batch_normalization_48 (Bat  (None, 20, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_32 (MaxPoolin  (None, 10, 80, 80, 16)   0
#  g3D)
#
#  conv3d_33 (Conv3D)          (None, 10, 80, 80, 32)    13856
#
#  activation_33 (Activation)  (None, 10, 80, 80, 32)    0
#
#  batch_normalization_49 (Bat  (None, 10, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_33 (MaxPoolin  (None, 5, 40, 40, 32)    0
#  g3D)
#
#  conv3d_34 (Conv3D)          (None, 5, 40, 40, 64)     55360
#
#  activation_34 (Activation)  (None, 5, 40, 40, 64)     0
#
#  batch_normalization_50 (Bat  (None, 5, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_34 (MaxPoolin  (None, 2, 20, 20, 64)    0
#  g3D)
#
#  conv3d_35 (Conv3D)          (None, 2, 20, 20, 128)    221312
#
#  activation_35 (Activation)  (None, 2, 20, 20, 128)    0
#
#  batch_normalization_51 (Bat  (None, 2, 20, 20, 128)   512
#  chNormalization)
#
#  max_pooling3d_35 (MaxPoolin  (None, 1, 10, 10, 128)   0
#  g3D)
#
#  flatten_8 (Flatten)         (None, 12800)             0
#
#  dense_24 (Dense)            (None, 64)                819264
#
#  batch_normalization_52 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_16 (Dropout)        (None, 64)                0
#
#  dense_25 (Dense)            (None, 64)                4160
#
#  batch_normalization_53 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_17 (Dropout)        (None, 64)                0
#
#  dense_26 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 1,117,061
# Trainable params: 1,116,325
# Non-trainable params: 736
# _________________________________________________________________

# %%
print("Total Params:", conv_3d1_model.count_params())
history_model1 = conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1117061
# Epoch 1/20
# 17/17 [==============================] - ETA: 0s - loss: 1.6247 - categorical_accuracy: 0.4238
# Epoch 00001: val_loss improved from inf to 2.06692, saving model to model_init_2024-09-0111_35_48.705089/model-00001-1.62466-0.42383-2.06692-0.21000.keras
# 17/17 [==============================] - 120s 7s/step - loss: 1.6247 - categorical_accuracy: 0.4238 - val_loss: 2.0669 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/20
# 17/17 [==============================] - ETA: 0s - loss: 0.9987 - categorical_accuracy: 0.6124
# Epoch 00002: val_loss did not improve from 2.06692
# 17/17 [==============================] - 116s 7s/step - loss: 0.9987 - categorical_accuracy: 0.6124 - val_loss: 2.4330 - val_categorical_accuracy: 0.1900 - lr: 0.0010
# Epoch 3/20
# 17/17 [==============================] - ETA: 0s - loss: 0.6992 - categorical_accuracy: 0.7557
# Epoch 00003: val_loss did not improve from 2.06692
# 17/17 [==============================] - 113s 7s/step - loss: 0.6992 - categorical_accuracy: 0.7557 - val_loss: 2.7158 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 4/20
# 17/17 [==============================] - ETA: 0s - loss: 0.5924 - categorical_accuracy: 0.8009
# Epoch 00004: val_loss did not improve from 2.06692
# 17/17 [==============================] - 116s 7s/step - loss: 0.5924 - categorical_accuracy: 0.8009 - val_loss: 3.1922 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 5/20
# 17/17 [==============================] - ETA: 0s - loss: 0.4093 - categorical_accuracy: 0.8627
# Epoch 00005: val_loss did not improve from 2.06692
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 17/17 [==============================] - 119s 7s/step - loss: 0.4093 - categorical_accuracy: 0.8627 - val_loss: 3.7065 - val_categorical_accuracy: 0.1900 - lr: 0.0010
# Epoch 6/20
# 17/17 [==============================] - ETA: 0s - loss: 0.3040 - categorical_accuracy: 0.8989
# Epoch 00006: val_loss did not improve from 2.06692
# 17/17 [==============================] - 114s 7s/step - loss: 0.3040 - categorical_accuracy: 0.8989 - val_loss: 4.1220 - val_categorical_accuracy: 0.1900 - lr: 2.0000e-04
# Epoch 7/20
# 17/17 [==============================] - ETA: 0s - loss: 0.2855 - categorical_accuracy: 0.9080
# Epoch 00007: val_loss did not improve from 2.06692
# 17/17 [==============================] - 118s 7s/step - loss: 0.2855 - categorical_accuracy: 0.9080 - val_loss: 4.3531 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 8/20
# 17/17 [==============================] - ETA: 0s - loss: 0.2076 - categorical_accuracy: 0.9578
# Epoch 00008: val_loss did not improve from 2.06692
# 17/17 [==============================] - 121s 8s/step - loss: 0.2076 - categorical_accuracy: 0.9578 - val_loss: 5.0164 - val_categorical_accuracy: 0.1700 - lr: 2.0000e-04
# Epoch 9/20
# 17/17 [==============================] - ETA: 0s - loss: 0.2085 - categorical_accuracy: 0.9502
# Epoch 00009: val_loss did not improve from 2.06692
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 17/17 [==============================] - 117s 7s/step - loss: 0.2085 - categorical_accuracy: 0.9502 - val_loss: 4.6986 - val_categorical_accuracy: 0.2000 - lr: 2.0000e-04
# Epoch 10/20
# 17/17 [==============================] - ETA: 0s - loss: 0.1583 - categorical_accuracy: 0.9608
# Epoch 00010: val_loss did not improve from 2.06692
# 17/17 [==============================] - 118s 7s/step - loss: 0.1583 - categorical_accuracy: 0.9608 - val_loss: 4.9517 - val_categorical_accuracy: 0.2100 - lr: 4.0000e-05
# Epoch 11/20
# 17/17 [==============================] - ETA: 0s - loss: 0.1730 - categorical_accuracy: 0.9593
# Epoch 00011: val_loss did not improve from 2.06692
# 17/17 [==============================] - 117s 7s/step - loss: 0.1730 - categorical_accuracy: 0.9593 - val_loss: 4.5854 - val_categorical_accuracy: 0.2600 - lr: 4.0000e-05
# Epoch 00011: early stopping

# %%
plot(history_model1)

# %% [markdown]
# **Model is clearly overfitting.**. We can clearly see that val_accuracy and train accuracy is not improving. So early stopping

# %% [markdown]
# ## Model 2
# ### Adding dropout layers - Batch Size = 20 and No. of Epochs = 25

# %%
conv_3d2=ModelConv3D1()
conv_3d2.initialize_path(project_folder)
conv_3d2.initialize_image_properties(image_height=160,image_width=160)
conv_3d2.initialize_hyperparams(frames_to_sample=20,batch_size=20,num_epochs=25)
conv_3d2_model=conv_3d2.define_model(dense_neurons=256,dropout=0.5)
conv_3d2_model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_36 (Conv3D)          (None, 20, 160, 160, 16)  1312
#
#  activation_36 (Activation)  (None, 20, 160, 160, 16)  0
#
#  batch_normalization_54 (Bat  (None, 20, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_36 (MaxPoolin  (None, 10, 80, 80, 16)   0
#  g3D)
#
#  conv3d_37 (Conv3D)          (None, 10, 80, 80, 32)    13856
#
#  activation_37 (Activation)  (None, 10, 80, 80, 32)    0
#
#  batch_normalization_55 (Bat  (None, 10, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_37 (MaxPoolin  (None, 5, 40, 40, 32)    0
#  g3D)
#
#  conv3d_38 (Conv3D)          (None, 5, 40, 40, 64)     55360
#
#  activation_38 (Activation)  (None, 5, 40, 40, 64)     0
#
#  batch_normalization_56 (Bat  (None, 5, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_38 (MaxPoolin  (None, 2, 20, 20, 64)    0
#  g3D)
#
#  conv3d_39 (Conv3D)          (None, 2, 20, 20, 128)    221312
#
#  activation_39 (Activation)  (None, 2, 20, 20, 128)    0
#
#  batch_normalization_57 (Bat  (None, 2, 20, 20, 128)   512
#  chNormalization)
#
#  max_pooling3d_39 (MaxPoolin  (None, 1, 10, 10, 128)   0
#  g3D)
#
#  flatten_9 (Flatten)         (None, 12800)             0
#
#  dense_27 (Dense)            (None, 256)               3277056
#
#  batch_normalization_58 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 256)               0
#
#  dense_28 (Dense)            (None, 256)               65792
#
#  batch_normalization_59 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 256)               0
#
#  dense_29 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 3,638,981
# Trainable params: 3,637,477
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d2_model.count_params())
history_model2=conv_3d2.train_model(conv_3d2_model,augment_data=True)
# Out:
# Total Params: 3638981
# Epoch 1/25
# 34/34 [==============================] - ETA: 0s - loss: 1.8772 - categorical_accuracy: 0.4027
# Epoch 00001: val_loss improved from inf to 3.10625, saving model to model_init_2024-09-0111_58_39.630656/model-00001-1.87718-0.40271-3.10625-0.21000.keras
# 34/34 [==============================] - 224s 7s/step - loss: 1.8772 - categorical_accuracy: 0.4027 - val_loss: 3.1062 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/25
# 34/34 [==============================] - ETA: 0s - loss: 1.4324 - categorical_accuracy: 0.5106
# Epoch 00002: val_loss improved from 3.10625 to 2.52675, saving model to model_init_2024-09-0111_58_39.630656/model-00002-1.43236-0.51056-2.52675-0.21000.keras
# 34/34 [==============================] - 221s 7s/step - loss: 1.4324 - categorical_accuracy: 0.5106 - val_loss: 2.5267 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 3/25
# 34/34 [==============================] - ETA: 0s - loss: 1.1298 - categorical_accuracy: 0.5928
# Epoch 00003: val_loss did not improve from 2.52675
# 34/34 [==============================] - 222s 7s/step - loss: 1.1298 - categorical_accuracy: 0.5928 - val_loss: 3.1420 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 4/25
# 34/34 [==============================] - ETA: 0s - loss: 0.9633 - categorical_accuracy: 0.6531
# Epoch 00004: val_loss did not improve from 2.52675
# 34/34 [==============================] - 221s 7s/step - loss: 0.9633 - categorical_accuracy: 0.6531 - val_loss: 2.6666 - val_categorical_accuracy: 0.3500 - lr: 0.0010
# Epoch 5/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8261 - categorical_accuracy: 0.6870
# Epoch 00005: val_loss did not improve from 2.52675
# 34/34 [==============================] - 216s 7s/step - loss: 0.8261 - categorical_accuracy: 0.6870 - val_loss: 3.3909 - val_categorical_accuracy: 0.3000 - lr: 0.0010
# Epoch 6/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7171 - categorical_accuracy: 0.7383
# Epoch 00006: val_loss did not improve from 2.52675
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 34/34 [==============================] - 218s 7s/step - loss: 0.7171 - categorical_accuracy: 0.7383 - val_loss: 3.6487 - val_categorical_accuracy: 0.1900 - lr: 0.0010
# Epoch 7/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5840 - categorical_accuracy: 0.7670
# Epoch 00007: val_loss did not improve from 2.52675
# 34/34 [==============================] - 218s 7s/step - loss: 0.5840 - categorical_accuracy: 0.7670 - val_loss: 3.6513 - val_categorical_accuracy: 0.2600 - lr: 2.0000e-04
# Epoch 8/25
# 34/34 [==============================] - ETA: 0s - loss: 0.4973 - categorical_accuracy: 0.8167
# Epoch 00008: val_loss did not improve from 2.52675
# 34/34 [==============================] - 219s 7s/step - loss: 0.4973 - categorical_accuracy: 0.8167 - val_loss: 4.2121 - val_categorical_accuracy: 0.2900 - lr: 2.0000e-04
# Epoch 9/25
# 34/34 [==============================] - ETA: 0s - loss: 0.4798 - categorical_accuracy: 0.8198
# Epoch 00009: val_loss did not improve from 2.52675
# 34/34 [==============================] - 218s 7s/step - loss: 0.4798 - categorical_accuracy: 0.8198 - val_loss: 3.6607 - val_categorical_accuracy: 0.2800 - lr: 2.0000e-04
# Epoch 10/25
# 34/34 [==============================] - ETA: 0s - loss: 0.4298 - categorical_accuracy: 0.8281
# Epoch 00010: val_loss did not improve from 2.52675
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 34/34 [==============================] - 220s 7s/step - loss: 0.4298 - categorical_accuracy: 0.8281 - val_loss: 3.0452 - val_categorical_accuracy: 0.3100 - lr: 2.0000e-04
# Epoch 11/25
# 34/34 [==============================] - ETA: 0s - loss: 0.4332 - categorical_accuracy: 0.8288
# Epoch 00011: val_loss did not improve from 2.52675
# 34/34 [==============================] - 220s 7s/step - loss: 0.4332 - categorical_accuracy: 0.8288 - val_loss: 2.7182 - val_categorical_accuracy: 0.3400 - lr: 4.0000e-05
# Epoch 12/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3979 - categorical_accuracy: 0.8454
# Epoch 00012: val_loss improved from 2.52675 to 2.44939, saving model to model_init_2024-09-0111_58_39.630656/model-00012-0.39795-0.84540-2.44939-0.36000.keras
# 34/34 [==============================] - 223s 7s/step - loss: 0.3979 - categorical_accuracy: 0.8454 - val_loss: 2.4494 - val_categorical_accuracy: 0.3600 - lr: 4.0000e-05
# Epoch 13/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3723 - categorical_accuracy: 0.8522
# Epoch 00013: val_loss improved from 2.44939 to 2.16577, saving model to model_init_2024-09-0111_58_39.630656/model-00013-0.37234-0.85219-2.16577-0.36000.keras
# 34/34 [==============================] - 223s 7s/step - loss: 0.3723 - categorical_accuracy: 0.8522 - val_loss: 2.1658 - val_categorical_accuracy: 0.3600 - lr: 4.0000e-05
# Epoch 14/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3638 - categorical_accuracy: 0.8650
# Epoch 00014: val_loss improved from 2.16577 to 1.68551, saving model to model_init_2024-09-0111_58_39.630656/model-00014-0.36379-0.86501-1.68551-0.46000.keras
# 34/34 [==============================] - 221s 7s/step - loss: 0.3638 - categorical_accuracy: 0.8650 - val_loss: 1.6855 - val_categorical_accuracy: 0.4600 - lr: 4.0000e-05
# Epoch 15/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3447 - categorical_accuracy: 0.8725
# Epoch 00015: val_loss improved from 1.68551 to 1.48816, saving model to model_init_2024-09-0111_58_39.630656/model-00015-0.34467-0.87255-1.48816-0.51000.keras
# 34/34 [==============================] - 220s 7s/step - loss: 0.3447 - categorical_accuracy: 0.8725 - val_loss: 1.4882 - val_categorical_accuracy: 0.5100 - lr: 4.0000e-05
# Epoch 16/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3534 - categorical_accuracy: 0.8703
# Epoch 00016: val_loss improved from 1.48816 to 1.27355, saving model to model_init_2024-09-0111_58_39.630656/model-00016-0.35337-0.87029-1.27355-0.56000.keras
# 34/34 [==============================] - 217s 7s/step - loss: 0.3534 - categorical_accuracy: 0.8703 - val_loss: 1.2736 - val_categorical_accuracy: 0.5600 - lr: 4.0000e-05
# Epoch 17/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3775 - categorical_accuracy: 0.8597
# Epoch 00017: val_loss improved from 1.27355 to 0.93121, saving model to model_init_2024-09-0111_58_39.630656/model-00017-0.37751-0.85973-0.93121-0.68000.keras
# 34/34 [==============================] - 218s 7s/step - loss: 0.3775 - categorical_accuracy: 0.8597 - val_loss: 0.9312 - val_categorical_accuracy: 0.6800 - lr: 4.0000e-05
# Epoch 18/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3229 - categorical_accuracy: 0.8710
# Epoch 00018: val_loss did not improve from 0.93121
# 34/34 [==============================] - 221s 7s/step - loss: 0.3229 - categorical_accuracy: 0.8710 - val_loss: 1.0333 - val_categorical_accuracy: 0.6700 - lr: 4.0000e-05
# Epoch 19/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3378 - categorical_accuracy: 0.8793
# Epoch 00019: val_loss improved from 0.93121 to 0.74176, saving model to model_init_2024-09-0111_58_39.630656/model-00019-0.33782-0.87934-0.74176-0.76000.keras
# 34/34 [==============================] - 218s 7s/step - loss: 0.3378 - categorical_accuracy: 0.8793 - val_loss: 0.7418 - val_categorical_accuracy: 0.7600 - lr: 4.0000e-05
# Epoch 20/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3394 - categorical_accuracy: 0.8748
# Epoch 00020: val_loss improved from 0.74176 to 0.63431, saving model to model_init_2024-09-0111_58_39.630656/model-00020-0.33943-0.87481-0.63431-0.81000.keras
# 34/34 [==============================] - 218s 7s/step - loss: 0.3394 - categorical_accuracy: 0.8748 - val_loss: 0.6343 - val_categorical_accuracy: 0.8100 - lr: 4.0000e-05
# Epoch 21/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3049 - categorical_accuracy: 0.8937
# Epoch 00021: val_loss improved from 0.63431 to 0.58758, saving model to model_init_2024-09-0111_58_39.630656/model-00021-0.30487-0.89367-0.58758-0.78000.keras
# 34/34 [==============================] - 218s 7s/step - loss: 0.3049 - categorical_accuracy: 0.8937 - val_loss: 0.5876 - val_categorical_accuracy: 0.7800 - lr: 4.0000e-05
# Epoch 22/25
# 34/34 [==============================] - ETA: 0s - loss: 0.2795 - categorical_accuracy: 0.9020
# Epoch 00022: val_loss improved from 0.58758 to 0.38142, saving model to model_init_2024-09-0111_58_39.630656/model-00022-0.27950-0.90196-0.38142-0.84000.keras
# 34/34 [==============================] - 221s 7s/step - loss: 0.2795 - categorical_accuracy: 0.9020 - val_loss: 0.3814 - val_categorical_accuracy: 0.8400 - lr: 4.0000e-05
# Epoch 23/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3283 - categorical_accuracy: 0.8801
# Epoch 00023: val_loss did not improve from 0.38142
# 34/34 [==============================] - 221s 7s/step - loss: 0.3283 - categorical_accuracy: 0.8801 - val_loss: 0.5577 - val_categorical_accuracy: 0.8200 - lr: 4.0000e-05
# Epoch 24/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3080 - categorical_accuracy: 0.8884
# Epoch 00024: val_loss improved from 0.38142 to 0.34871, saving model to model_init_2024-09-0111_58_39.630656/model-00024-0.30796-0.88839-0.34871-0.88000.keras
# 34/34 [==============================] - 222s 7s/step - loss: 0.3080 - categorical_accuracy: 0.8884 - val_loss: 0.3487 - val_categorical_accuracy: 0.8800 - lr: 4.0000e-05
# Epoch 25/25
# 27/34 [======================>.......] - ETA: 43s - loss: 0.3066 - categorical_accuracy: 0.8824

# %%
plot(history_model2)

# %% [markdown]
# ##### We can see  val_loss is 0.35 Best accuracy attained
# - Best weights save automatically. The validation accuracy is **80% and training accuracy 88.8%**.
# - Next we will try to reduce the filter size and image resolution and see if get better results. Moreover since we see minor oscillations  in loss, let's try lowering the learning rate to 0.0002

# %% [markdown]
# ## Model 3
# ### Reduce filter size to (2,2,2) and image res to 120 x  120, - Batch Size = 30 and No. of Epochs = 25

# %%
class ModelConv3D3(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))
        
        optimiser = Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d3=ModelConv3D3()
conv_3d3.initialize_path(project_folder)
conv_3d3.initialize_image_properties(image_height=120,image_width=120)
conv_3d3.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=25)
conv_3d3_model=conv_3d3.define_model(filtersize=(2,2,2),dense_neurons=256,dropout=0.5)
conv_3d3_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_4 (Conv3D)           (None, 16, 120, 120, 16)  400
#
#  activation_4 (Activation)   (None, 16, 120, 120, 16)  0
#
#  batch_normalization_6 (Batc  (None, 16, 120, 120, 16)  64
#  hNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 8, 60, 60, 16)    0
#  3D)
#
#  conv3d_5 (Conv3D)           (None, 8, 60, 60, 32)     4128
#
#  activation_5 (Activation)   (None, 8, 60, 60, 32)     0
#
#  batch_normalization_7 (Batc  (None, 8, 60, 60, 32)    128
#  hNormalization)
#
#  max_pooling3d_5 (MaxPooling  (None, 4, 30, 30, 32)    0
#  3D)
#
#  conv3d_6 (Conv3D)           (None, 4, 30, 30, 64)     16448
#
#  activation_6 (Activation)   (None, 4, 30, 30, 64)     0
#
#  batch_normalization_8 (Batc  (None, 4, 30, 30, 64)    256
#  hNormalization)
#
#  max_pooling3d_6 (MaxPooling  (None, 2, 15, 15, 64)    0
#  3D)
#
#  conv3d_7 (Conv3D)           (None, 2, 15, 15, 128)    65664
#
#  activation_7 (Activation)   (None, 2, 15, 15, 128)    0
#
#  batch_normalization_9 (Batc  (None, 2, 15, 15, 128)   512
#  hNormalization)
#
#  max_pooling3d_7 (MaxPooling  (None, 1, 7, 7, 128)     0
#  3D)
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  dense_3 (Dense)             (None, 256)               1605888
#
#  batch_normalization_10 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  batch_normalization_11 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 1,762,613
# Trainable params: 1,761,109
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d3_model.count_params())
history_model3=conv_3d3.train_model(conv_3d3_model,augment_data=True)
# Out:
# Total Params: 1762613
# Epoch 1/25
# 2024-09-01 18:25:46.795266: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 23/23 [==============================] - ETA: 0s - loss: 2.1063 - categorical_accuracy: 0.3514
# Epoch 00001: val_loss improved from inf to 1.69782, saving model to model_init_2024-09-0118_25_37.295708/model-00001-2.10628-0.35143-1.69782-0.16000.keras
# 23/23 [==============================] - 177s 8s/step - loss: 2.1063 - categorical_accuracy: 0.3514 - val_loss: 1.6978 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 2/25
# 23/23 [==============================] - ETA: 0s - loss: 1.4396 - categorical_accuracy: 0.5158
# Epoch 00002: val_loss did not improve from 1.69782
# 23/23 [==============================] - 168s 8s/step - loss: 1.4396 - categorical_accuracy: 0.5158 - val_loss: 2.2210 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 3/25
# 23/23 [==============================] - ETA: 0s - loss: 1.2427 - categorical_accuracy: 0.5784
# Epoch 00003: val_loss did not improve from 1.69782
# 23/23 [==============================] - 162s 7s/step - loss: 1.2427 - categorical_accuracy: 0.5784 - val_loss: 3.0833 - val_categorical_accuracy: 0.1200 - lr: 2.0000e-04
# Epoch 4/25
# 23/23 [==============================] - ETA: 0s - loss: 1.0884 - categorical_accuracy: 0.6154
# Epoch 00004: val_loss did not improve from 1.69782
# 23/23 [==============================] - 153s 7s/step - loss: 1.0884 - categorical_accuracy: 0.6154 - val_loss: 3.9107 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 5/25
# 23/23 [==============================] - ETA: 0s - loss: 1.0305 - categorical_accuracy: 0.6214
# Epoch 00005: val_loss did not improve from 1.69782
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 23/23 [==============================] - 152s 7s/step - loss: 1.0305 - categorical_accuracy: 0.6214 - val_loss: 4.9728 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 6/25
# 23/23 [==============================] - ETA: 0s - loss: 0.9679 - categorical_accuracy: 0.6652
# Epoch 00006: val_loss did not improve from 1.69782
# 23/23 [==============================] - 151s 7s/step - loss: 0.9679 - categorical_accuracy: 0.6652 - val_loss: 5.4277 - val_categorical_accuracy: 0.1700 - lr: 4.0000e-05
# Epoch 7/25
# 23/23 [==============================] - ETA: 0s - loss: 0.9519 - categorical_accuracy: 0.6508
# Epoch 00007: val_loss did not improve from 1.69782
# 23/23 [==============================] - 153s 7s/step - loss: 0.9519 - categorical_accuracy: 0.6508 - val_loss: 6.4406 - val_categorical_accuracy: 0.1700 - lr: 4.0000e-05
# Epoch 8/25
# 23/23 [==============================] - ETA: 0s - loss: 0.9071 - categorical_accuracy: 0.6689
# Epoch 00008: val_loss did not improve from 1.69782
# 23/23 [==============================] - 151s 7s/step - loss: 0.9071 - categorical_accuracy: 0.6689 - val_loss: 6.4396 - val_categorical_accuracy: 0.3000 - lr: 4.0000e-05
# Epoch 9/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8968 - categorical_accuracy: 0.6652
# Epoch 00009: val_loss did not improve from 1.69782
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 23/23 [==============================] - 153s 7s/step - loss: 0.8968 - categorical_accuracy: 0.6652 - val_loss: 6.9427 - val_categorical_accuracy: 0.2700 - lr: 4.0000e-05
# Epoch 10/25
# 23/23 [==============================] - ETA: 0s - loss: 0.9050 - categorical_accuracy: 0.6689
# Epoch 00010: val_loss did not improve from 1.69782
# 23/23 [==============================] - 150s 7s/step - loss: 0.9050 - categorical_accuracy: 0.6689 - val_loss: 7.1150 - val_categorical_accuracy: 0.2200 - lr: 8.0000e-06
# Epoch 11/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8756 - categorical_accuracy: 0.6848
# Epoch 00011: val_loss did not improve from 1.69782
# 23/23 [==============================] - 151s 7s/step - loss: 0.8756 - categorical_accuracy: 0.6848 - val_loss: 7.3240 - val_categorical_accuracy: 0.2800 - lr: 8.0000e-06
# Epoch 00011: early stopping

# %%
plot(history_model3)

# %% [markdown]
# ##### Early stopping at 23 epohs as train accuracy ad val accuracy did not improve.
# -Val accuracy: 28% train accuracy is 68%

# %% [markdown]
# # Model 4 - Reducing the number of parameters again

# %%
class ModelConv3D4(ModelBuilder):
    
    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (3, 3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser=Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d4=ModelConv3D4()
conv_3d4.initialize_path(project_folder)
conv_3d4.initialize_image_properties(image_height=120,image_width=120)
conv_3d4.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d4_model=conv_3d4.define_model(dense_neurons=64,dropout=0.25)
conv_3d4_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_8 (Conv3D)           (None, 16, 120, 120, 16)  1312
#
#  activation_8 (Activation)   (None, 16, 120, 120, 16)  0
#
#  batch_normalization_12 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_8 (MaxPooling  (None, 8, 60, 60, 16)    0
#  3D)
#
#  conv3d_9 (Conv3D)           (None, 8, 60, 60, 32)     13856
#
#  activation_9 (Activation)   (None, 8, 60, 60, 32)     0
#
#  batch_normalization_13 (Bat  (None, 8, 60, 60, 32)    128
#  chNormalization)
#
#  max_pooling3d_9 (MaxPooling  (None, 4, 30, 30, 32)    0
#  3D)
#
#  conv3d_10 (Conv3D)          (None, 4, 30, 30, 64)     16448
#
#  activation_10 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_14 (Bat  (None, 4, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_10 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
#  conv3d_11 (Conv3D)          (None, 2, 15, 15, 128)    65664
#
#  activation_11 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_15 (Bat  (None, 2, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_11 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_2 (Flatten)         (None, 6272)              0
#
#  dense_6 (Dense)             (None, 64)                401472
#
#  batch_normalization_16 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  batch_normalization_17 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 504,709
# Trainable params: 503,973
# Non-trainable params: 736
# _________________________________________________________________

# %%
print("Total Params:", conv_3d4_model.count_params())
history_model4=conv_3d4.train_model(conv_3d4_model,augment_data=True)
# Out:
# Total Params: 504709
# Epoch 1/25
# 34/34 [==============================] - ETA: 0s - loss: 1.7825 - categorical_accuracy: 0.3462
# Epoch 00001: val_loss improved from inf to 1.89737, saving model to model_init_2024-09-0118_58_07.986635/model-00001-1.78249-0.34615-1.89737-0.21000.keras
# 34/34 [==============================] - 153s 5s/step - loss: 1.7825 - categorical_accuracy: 0.3462 - val_loss: 1.8974 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 2/25
# 34/34 [==============================] - ETA: 0s - loss: 1.3186 - categorical_accuracy: 0.4796
# Epoch 00002: val_loss did not improve from 1.89737
# 34/34 [==============================] - 157s 5s/step - loss: 1.3186 - categorical_accuracy: 0.4796 - val_loss: 2.6099 - val_categorical_accuracy: 0.1700 - lr: 2.0000e-04
# Epoch 3/25
# 34/34 [==============================] - ETA: 0s - loss: 1.1048 - categorical_accuracy: 0.5769
# Epoch 00003: val_loss did not improve from 1.89737
# 34/34 [==============================] - 154s 5s/step - loss: 1.1048 - categorical_accuracy: 0.5769 - val_loss: 3.0356 - val_categorical_accuracy: 0.2300 - lr: 2.0000e-04
# Epoch 4/25
# 34/34 [==============================] - ETA: 0s - loss: 0.9799 - categorical_accuracy: 0.6305
# Epoch 00004: val_loss did not improve from 1.89737
# 34/34 [==============================] - 149s 5s/step - loss: 0.9799 - categorical_accuracy: 0.6305 - val_loss: 3.9385 - val_categorical_accuracy: 0.1700 - lr: 2.0000e-04
# Epoch 5/25
# 34/34 [==============================] - ETA: 0s - loss: 0.9203 - categorical_accuracy: 0.6493
# Epoch 00005: val_loss did not improve from 1.89737
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 34/34 [==============================] - 149s 4s/step - loss: 0.9203 - categorical_accuracy: 0.6493 - val_loss: 4.7347 - val_categorical_accuracy: 0.1800 - lr: 2.0000e-04
# Epoch 6/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8354 - categorical_accuracy: 0.6795
# Epoch 00006: val_loss did not improve from 1.89737
# 34/34 [==============================] - 148s 4s/step - loss: 0.8354 - categorical_accuracy: 0.6795 - val_loss: 4.5544 - val_categorical_accuracy: 0.1800 - lr: 4.0000e-05
# Epoch 7/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7641 - categorical_accuracy: 0.7134
# Epoch 00007: val_loss did not improve from 1.89737
# 34/34 [==============================] - 151s 5s/step - loss: 0.7641 - categorical_accuracy: 0.7134 - val_loss: 4.6349 - val_categorical_accuracy: 0.2100 - lr: 4.0000e-05
# Epoch 8/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7405 - categorical_accuracy: 0.7225
# Epoch 00008: val_loss did not improve from 1.89737
# 34/34 [==============================] - 156s 5s/step - loss: 0.7405 - categorical_accuracy: 0.7225 - val_loss: 4.2298 - val_categorical_accuracy: 0.1900 - lr: 4.0000e-05
# Epoch 9/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7346 - categorical_accuracy: 0.7157
# Epoch 00009: val_loss did not improve from 1.89737
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 34/34 [==============================] - 149s 4s/step - loss: 0.7346 - categorical_accuracy: 0.7157 - val_loss: 3.7235 - val_categorical_accuracy: 0.2600 - lr: 4.0000e-05
# Epoch 10/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7118 - categorical_accuracy: 0.7376
# Epoch 00010: val_loss did not improve from 1.89737
# 34/34 [==============================] - 150s 5s/step - loss: 0.7118 - categorical_accuracy: 0.7376 - val_loss: 3.7615 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-06
# Epoch 11/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7362 - categorical_accuracy: 0.7315
# Epoch 00011: val_loss did not improve from 1.89737
# 34/34 [==============================] - 156s 5s/step - loss: 0.7362 - categorical_accuracy: 0.7315 - val_loss: 3.2201 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-06
# Epoch 00011: early stopping

# %%
plot(history_model4)

# %% [markdown]
# For the above low memory foot print model the best validation accuracy is 0.25. which is not improing so the model was early stopped.

# %% [markdown]
# ## Model 5 - CNN- LSTM Model

# %%
class RNNCNN1(ModelBuilder):
    
    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):

        model = Sequential()

        model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                  input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(256, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        #model.add(TimeDistributed(Conv2D(512, (2, 2) , padding='valid', activation='relu')))
       # model.add(TimeDistributed(BatchNormalization()))
       # model.add(TimeDistributed(MaxPooling2D((2, 2))))

        model.add(TimeDistributed(Flatten()))


        model.add(LSTM(lstm_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        optimiser = Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
rnn_cnn1=RNNCNN1()
rnn_cnn1.initialize_path(project_folder)
rnn_cnn1.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn1.initialize_hyperparams(frames_to_sample=18,batch_size=20,num_epochs=20)
rnn_cnn1_model=rnn_cnn1.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn1_model.summary()
# Out:
# 2024-09-02 07:41:07.956301: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-09-02 07:41:07.956385: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14800 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:1c:00.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 18, 120, 120, 16)  448
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 18, 120, 120, 16)  64
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 18, 60, 60, 16)   0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 18, 60, 60, 32)   4640
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 18, 60, 60, 32)   128
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 18, 30, 30, 32)   0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 18, 30, 30, 64)   18496
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 18, 30, 30, 64)   256
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 18, 15, 15, 64)   0
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 18, 15, 15, 128)  73856
#  tributed)
#
#  time_distributed_10 (TimeDi  (None, 18, 15, 15, 128)  512
#  stributed)
#
#  time_distributed_11 (TimeDi  (None, 18, 7, 7, 128)    0
#  stributed)
#
#  time_distributed_12 (TimeDi  (None, 18, 7, 7, 256)    295168
#  stributed)
#
#  time_distributed_13 (TimeDi  (None, 18, 7, 7, 256)    1024
#  stributed)
#
#  time_distributed_14 (TimeDi  (None, 18, 3, 3, 256)    0
#  stributed)
#
#  time_distributed_15 (TimeDi  (None, 18, 2304)         0
#  stributed)
#
#  lstm (LSTM)                 (None, 128)               1245696
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 1,657,445
# Trainable params: 1,656,453
# Non-trainable params: 992
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn1_model.count_params())
history_model5=rnn_cnn1.train_model(rnn_cnn1_model,augment_data=True)
# Out:
# Total Params: 1657445
# Epoch 1/20
# 34/34 [==============================] - ETA: 0s - loss: 1.3941 - categorical_accuracy: 0.4080
# Epoch 00001: val_loss improved from inf to 1.99051, saving model to model_init_2024-09-0119_29_30.298728/model-00001-1.39411-0.40799-1.99051-0.21000.keras
# 34/34 [==============================] - 205s 6s/step - loss: 1.3941 - categorical_accuracy: 0.4080 - val_loss: 1.9905 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 1.1419 - categorical_accuracy: 0.5309
# Epoch 00002: val_loss did not improve from 1.99051
# 34/34 [==============================] - 184s 6s/step - loss: 1.1419 - categorical_accuracy: 0.5309 - val_loss: 2.3776 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 0.9793 - categorical_accuracy: 0.5973
# Epoch 00003: val_loss did not improve from 1.99051
# 34/34 [==============================] - 171s 5s/step - loss: 0.9793 - categorical_accuracy: 0.5973 - val_loss: 2.3773 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - loss: 0.9031 - categorical_accuracy: 0.6395
# Epoch 00004: val_loss did not improve from 1.99051
# 34/34 [==============================] - 172s 5s/step - loss: 0.9031 - categorical_accuracy: 0.6395 - val_loss: 2.6934 - val_categorical_accuracy: 0.1400 - lr: 0.0010
# Epoch 5/20
# 34/34 [==============================] - ETA: 0s - loss: 0.8107 - categorical_accuracy: 0.6991
# Epoch 00005: val_loss improved from 1.99051 to 1.98298, saving model to model_init_2024-09-0119_29_30.298728/model-00005-0.81074-0.69910-1.98298-0.25000.keras
# 34/34 [==============================] - 168s 5s/step - loss: 0.8107 - categorical_accuracy: 0.6991 - val_loss: 1.9830 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 6/20
# 34/34 [==============================] - ETA: 0s - loss: 0.7577 - categorical_accuracy: 0.6968
# Epoch 00006: val_loss did not improve from 1.98298
# 34/34 [==============================] - 167s 5s/step - loss: 0.7577 - categorical_accuracy: 0.6968 - val_loss: 2.4666 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 7/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6765 - categorical_accuracy: 0.7398
# Epoch 00007: val_loss did not improve from 1.98298
# 34/34 [==============================] - 168s 5s/step - loss: 0.6765 - categorical_accuracy: 0.7398 - val_loss: 2.0524 - val_categorical_accuracy: 0.2800 - lr: 0.0010
# Epoch 8/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6551 - categorical_accuracy: 0.7511
# Epoch 00008: val_loss did not improve from 1.98298
# 34/34 [==============================] - 170s 5s/step - loss: 0.6551 - categorical_accuracy: 0.7511 - val_loss: 2.2933 - val_categorical_accuracy: 0.3700 - lr: 0.0010
# Epoch 9/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6099 - categorical_accuracy: 0.7760
# Epoch 00009: val_loss did not improve from 1.98298
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 34/34 [==============================] - 169s 5s/step - loss: 0.6099 - categorical_accuracy: 0.7760 - val_loss: 2.9186 - val_categorical_accuracy: 0.3200 - lr: 0.0010
# Epoch 10/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4335 - categorical_accuracy: 0.8499
# Epoch 00010: val_loss did not improve from 1.98298
# 34/34 [==============================] - 172s 5s/step - loss: 0.4335 - categorical_accuracy: 0.8499 - val_loss: 2.4364 - val_categorical_accuracy: 0.3500 - lr: 2.0000e-04
# Epoch 11/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3437 - categorical_accuracy: 0.8763
# Epoch 00011: val_loss did not improve from 1.98298
# 34/34 [==============================] - 170s 5s/step - loss: 0.3437 - categorical_accuracy: 0.8763 - val_loss: 2.3616 - val_categorical_accuracy: 0.3600 - lr: 2.0000e-04
# Epoch 12/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2866 - categorical_accuracy: 0.9087
# Epoch 00012: val_loss improved from 1.98298 to 1.92190, saving model to model_init_2024-09-0119_29_30.298728/model-00012-0.28656-0.90875-1.92190-0.44000.keras
# 34/34 [==============================] - 171s 5s/step - loss: 0.2866 - categorical_accuracy: 0.9087 - val_loss: 1.9219 - val_categorical_accuracy: 0.4400 - lr: 2.0000e-04
# Epoch 13/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2659 - categorical_accuracy: 0.9072
# Epoch 00013: val_loss did not improve from 1.92190
# 34/34 [==============================] - 172s 5s/step - loss: 0.2659 - categorical_accuracy: 0.9072 - val_loss: 2.0742 - val_categorical_accuracy: 0.3900 - lr: 2.0000e-04
# Epoch 14/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2449 - categorical_accuracy: 0.9170
# Epoch 00014: val_loss improved from 1.92190 to 1.62169, saving model to model_init_2024-09-0119_29_30.298728/model-00014-0.24495-0.91704-1.62169-0.51000.keras
# 34/34 [==============================] - 171s 5s/step - loss: 0.2449 - categorical_accuracy: 0.9170 - val_loss: 1.6217 - val_categorical_accuracy: 0.5100 - lr: 2.0000e-04
# Epoch 15/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2118 - categorical_accuracy: 0.9367
# Epoch 00015: val_loss improved from 1.62169 to 1.39362, saving model to model_init_2024-09-0119_29_30.298728/model-00015-0.21177-0.93665-1.39362-0.56000.keras
# 34/34 [==============================] - 168s 5s/step - loss: 0.2118 - categorical_accuracy: 0.9367 - val_loss: 1.3936 - val_categorical_accuracy: 0.5600 - lr: 2.0000e-04
# Epoch 16/20
# 34/34 [==============================] - ETA: 0s - loss: 0.1787 - categorical_accuracy: 0.9412
# Epoch 00016: val_loss improved from 1.39362 to 1.23585, saving model to model_init_2024-09-0119_29_30.298728/model-00016-0.17870-0.94118-1.23585-0.61000.keras
# 34/34 [==============================] - 170s 5s/step - loss: 0.1787 - categorical_accuracy: 0.9412 - val_loss: 1.2358 - val_categorical_accuracy: 0.6100 - lr: 2.0000e-04
# Epoch 17/20
# 34/34 [==============================] - ETA: 0s - loss: 0.1691 - categorical_accuracy: 0.9465
# Epoch 00017: val_loss improved from 1.23585 to 1.13465, saving model to model_init_2024-09-0119_29_30.298728/model-00017-0.16913-0.94646-1.13465-0.61000.keras
# 34/34 [==============================] - 171s 5s/step - loss: 0.1691 - categorical_accuracy: 0.9465 - val_loss: 1.1347 - val_categorical_accuracy: 0.6100 - lr: 2.0000e-04
# Epoch 18/20
# 34/34 [==============================] - ETA: 0s - loss: 0.1579 - categorical_accuracy: 0.9555
# Epoch 00018: val_loss improved from 1.13465 to 0.74500, saving model to model_init_2024-09-0119_29_30.298728/model-00018-0.15786-0.95551-0.74500-0.72000.keras
# 34/34 [==============================] - 169s 5s/step - loss: 0.1579 - categorical_accuracy: 0.9555 - val_loss: 0.7450 - val_categorical_accuracy: 0.7200 - lr: 2.0000e-04
# Epoch 19/20
# 34/34 [==============================] - ETA: 0s - loss: 0.1250 - categorical_accuracy: 0.9615
# Epoch 00019: val_loss did not improve from 0.74500
# 34/34 [==============================] - 173s 5s/step - loss: 0.1250 - categorical_accuracy: 0.9615 - val_loss: 1.0401 - val_categorical_accuracy: 0.6200 - lr: 2.0000e-04
# Epoch 20/20
# 34/34 [==============================] - ETA: 0s - loss: 0.1400 - categorical_accuracy: 0.9555
# Epoch 00020: val_loss improved from 0.74500 to 0.63038, saving model to model_init_2024-09-0119_29_30.298728/model-00020-0.13995-0.95551-0.63038-0.75000.keras
# 34/34 [==============================] - 171s 5s/step - loss: 0.1400 - categorical_accuracy: 0.9555 - val_loss: 0.6304 - val_categorical_accuracy: 0.7500 - lr: 2.0000e-04

# %%
plot(history_model5)

# %% [markdown]
# ##### For CNN - LSTM model we get a best validation accuracy of 75%
# -As we see more cases of overfitting, lets augment the data with slight rotation as well and run the same set of models again

# %% [markdown]
# # With Augmentation

# %% [markdown]
# ## Let's apply some data augmentation & check the model performance.

# %%
class ModelBuilderMoreAugmentation(metaclass= abc.ABCMeta):
    
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
        
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
          
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx): 
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=resize(image,(self.image_height,self.image_width,3))
            

                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=resize(cropped,(self.image_height,self.image_width,3))
                    
                    M = cv2.getRotationMatrix2D((self.image_width//2,self.image_height//2),
                                                np.random.randint(-10,10), 1.0)
                    rotated = cv2.warpAffine(image_resized, M, (self.image_width, self.image_height))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (rotated[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (rotated[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (rotated[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        callbacks_list = [checkpoint, LR]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %%
class Test(ModelBuilderMoreAugmentation):
    def define_model(self):
        pass

test_generator=Test()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=160,image_width=160)
test_generator.initialize_hyperparams(frames_to_sample=30,batch_size=3,num_epochs=1)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=True)
batch_data, batch_labels=next(g)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,29,:,:,:])   
axes[1].imshow(batch_data[3,29,:,:,:]) 
plt.show()

# %% [markdown]
# ## Let's apply some data augmentation & check the model performance.

# %%
class ModelBuilderMoreAugmentation(metaclass= abc.ABCMeta):
    
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
        
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
          
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx): 
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=resize(image,(self.image_height,self.image_width,3))
            

                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=resize(cropped,(self.image_height,self.image_width,3))
                    
                    M = cv2.getRotationMatrix2D((self.image_width//2,self.image_height//2),
                                                np.random.randint(-10,10), 1.0)
                    rotated = cv2.warpAffine(image_resized, M, (self.image_width, self.image_height))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (rotated[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (rotated[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (rotated[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        callbacks_list = [checkpoint, LR]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %%
class Test(ModelBuilderMoreAugmentation):
    def define_model(self):
        pass

test_generator=Test()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=160,image_width=160)
test_generator.initialize_hyperparams(frames_to_sample=30,batch_size=3,num_epochs=1)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=True)
batch_data, batch_labels=next(g)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,29,:,:,:])   
axes[1].imshow(batch_data[3,29,:,:,:]) 
plt.show()

# %% [markdown]
# ## Model 9 with Augmentation
# ### (3,3,3) Filter & 160x160 Image resolution - similar to Model 2

# %%
class ModelConv3D9(ModelBuilderMoreAugmentation):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d9=ModelConv3D9()
conv_3d9.initialize_path(project_folder)
conv_3d9.initialize_image_properties(image_height=160,image_width=160)
conv_3d9.initialize_hyperparams(frames_to_sample=20,batch_size=20,num_epochs=20)
conv_3d9_model=conv_3d9.define_model(dense_neurons=256,dropout=0.5)
conv_3d9_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_4 (Conv3D)           (None, 20, 160, 160, 16)  1312
#
#  activation_4 (Activation)   (None, 20, 160, 160, 16)  0
#
#  batch_normalization_11 (Bat  (None, 20, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 10, 80, 80, 16)   0
#  3D)
#
#  conv3d_5 (Conv3D)           (None, 10, 80, 80, 32)    13856
#
#  activation_5 (Activation)   (None, 10, 80, 80, 32)    0
#
#  batch_normalization_12 (Bat  (None, 10, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_5 (MaxPooling  (None, 5, 40, 40, 32)    0
#  3D)
#
#  conv3d_6 (Conv3D)           (None, 5, 40, 40, 64)     55360
#
#  activation_6 (Activation)   (None, 5, 40, 40, 64)     0
#
#  batch_normalization_13 (Bat  (None, 5, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_6 (MaxPooling  (None, 2, 20, 20, 64)    0
#  3D)
#
#  conv3d_7 (Conv3D)           (None, 2, 20, 20, 128)    221312
#
#  activation_7 (Activation)   (None, 2, 20, 20, 128)    0
#
#  batch_normalization_14 (Bat  (None, 2, 20, 20, 128)   512
#  chNormalization)
#
#  max_pooling3d_7 (MaxPooling  (None, 1, 10, 10, 128)   0
#  3D)
#
#  flatten_2 (Flatten)         (None, 12800)             0
#
#  dense_5 (Dense)             (None, 256)               3277056
#
#  batch_normalization_15 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 256)               65792
#
#  batch_normalization_16 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 3,638,981
# Trainable params: 3,637,477
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d9_model.count_params())
history_model9=conv_3d9.train_model(conv_3d9_model,augment_data=True)
# Out:
# Total Params: 3638981
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 2024-09-02 07:47:33.330854: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 34/34 [==============================] - ETA: 0s - loss: 1.7877 - categorical_accuracy: 0.4208
# Epoch 00001: saving model to model_init_2024-09-0207_47_24.753026/model-00001-1.78771-0.42081-2.61455-0.21000.h5
# 34/34 [==============================] - 228s 7s/step - loss: 1.7877 - categorical_accuracy: 0.4208 - val_loss: 2.6146 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 1.3408 - categorical_accuracy: 0.5354
# Epoch 00002: saving model to model_init_2024-09-0207_47_24.753026/model-00002-1.34078-0.53544-3.85597-0.17000.h5
# 34/34 [==============================] - 223s 7s/step - loss: 1.3408 - categorical_accuracy: 0.5354 - val_loss: 3.8560 - val_categorical_accuracy: 0.1700 - lr: 0.0010
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 1.1843 - categorical_accuracy: 0.5679
# Epoch 00003: saving model to model_init_2024-09-0207_47_24.753026/model-00003-1.18433-0.56787-3.36952-0.23000.h5
# 34/34 [==============================] - 221s 7s/step - loss: 1.1843 - categorical_accuracy: 0.5679 - val_loss: 3.3695 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - loss: 1.0729 - categorical_accuracy: 0.6222
# Epoch 00004: saving model to model_init_2024-09-0207_47_24.753026/model-00004-1.07293-0.62217-4.98839-0.18000.h5
# 34/34 [==============================] - 222s 7s/step - loss: 1.0729 - categorical_accuracy: 0.6222 - val_loss: 4.9884 - val_categorical_accuracy: 0.1800 - lr: 0.0010
# Epoch 5/20
# 34/34 [==============================] - ETA: 0s - loss: 0.8923 - categorical_accuracy: 0.6689
# Epoch 00005: saving model to model_init_2024-09-0207_47_24.753026/model-00005-0.89235-0.66893-6.51513-0.20000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 34/34 [==============================] - 221s 7s/step - loss: 0.8923 - categorical_accuracy: 0.6689 - val_loss: 6.5151 - val_categorical_accuracy: 0.2000 - lr: 0.0010
# Epoch 6/20
# 34/34 [==============================] - ETA: 0s - loss: 0.7865 - categorical_accuracy: 0.7029
# Epoch 00006: saving model to model_init_2024-09-0207_47_24.753026/model-00006-0.78648-0.70287-5.84121-0.21000.h5
# 34/34 [==============================] - 219s 7s/step - loss: 0.7865 - categorical_accuracy: 0.7029 - val_loss: 5.8412 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 7/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6160 - categorical_accuracy: 0.7647
# Epoch 00007: saving model to model_init_2024-09-0207_47_24.753026/model-00007-0.61602-0.76471-5.50452-0.20000.h5
# 34/34 [==============================] - 221s 7s/step - loss: 0.6160 - categorical_accuracy: 0.7647 - val_loss: 5.5045 - val_categorical_accuracy: 0.2000 - lr: 2.0000e-04
# Epoch 8/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5713 - categorical_accuracy: 0.7873
# Epoch 00008: saving model to model_init_2024-09-0207_47_24.753026/model-00008-0.57125-0.78733-5.51332-0.24000.h5
# 34/34 [==============================] - 220s 7s/step - loss: 0.5713 - categorical_accuracy: 0.7873 - val_loss: 5.5133 - val_categorical_accuracy: 0.2400 - lr: 2.0000e-04
# Epoch 9/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5941 - categorical_accuracy: 0.7775
# Epoch 00009: saving model to model_init_2024-09-0207_47_24.753026/model-00009-0.59407-0.77753-5.49309-0.24000.h5
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 34/34 [==============================] - 221s 7s/step - loss: 0.5941 - categorical_accuracy: 0.7775 - val_loss: 5.4931 - val_categorical_accuracy: 0.2400 - lr: 2.0000e-04
# Epoch 10/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5680 - categorical_accuracy: 0.7873
# Epoch 00010: saving model to model_init_2024-09-0207_47_24.753026/model-00010-0.56801-0.78733-4.64271-0.28000.h5
# 34/34 [==============================] - 223s 7s/step - loss: 0.5680 - categorical_accuracy: 0.7873 - val_loss: 4.6427 - val_categorical_accuracy: 0.2800 - lr: 4.0000e-05
# Epoch 11/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4767 - categorical_accuracy: 0.8190
# Epoch 00011: saving model to model_init_2024-09-0207_47_24.753026/model-00011-0.47666-0.81900-4.09931-0.25000.h5
# 34/34 [==============================] - 222s 7s/step - loss: 0.4767 - categorical_accuracy: 0.8190 - val_loss: 4.0993 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-05
# Epoch 12/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5218 - categorical_accuracy: 0.8032
# Epoch 00012: saving model to model_init_2024-09-0207_47_24.753026/model-00012-0.52178-0.80317-3.44574-0.32000.h5
# 34/34 [==============================] - 220s 7s/step - loss: 0.5218 - categorical_accuracy: 0.8032 - val_loss: 3.4457 - val_categorical_accuracy: 0.3200 - lr: 4.0000e-05
# Epoch 13/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4965 - categorical_accuracy: 0.8213
# Epoch 00013: saving model to model_init_2024-09-0207_47_24.753026/model-00013-0.49653-0.82127-4.06044-0.28000.h5
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 34/34 [==============================] - 227s 7s/step - loss: 0.4965 - categorical_accuracy: 0.8213 - val_loss: 4.0604 - val_categorical_accuracy: 0.2800 - lr: 4.0000e-05
# Epoch 14/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5114 - categorical_accuracy: 0.8115
# Epoch 00014: saving model to model_init_2024-09-0207_47_24.753026/model-00014-0.51143-0.81146-2.73905-0.41000.h5
# 34/34 [==============================] - 223s 7s/step - loss: 0.5114 - categorical_accuracy: 0.8115 - val_loss: 2.7390 - val_categorical_accuracy: 0.4100 - lr: 8.0000e-06
# Epoch 15/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5137 - categorical_accuracy: 0.7979
# Epoch 00015: saving model to model_init_2024-09-0207_47_24.753026/model-00015-0.51373-0.79789-2.06757-0.46000.h5
# 34/34 [==============================] - 226s 7s/step - loss: 0.5137 - categorical_accuracy: 0.7979 - val_loss: 2.0676 - val_categorical_accuracy: 0.4600 - lr: 8.0000e-06
# Epoch 16/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5062 - categorical_accuracy: 0.8235
# Epoch 00016: saving model to model_init_2024-09-0207_47_24.753026/model-00016-0.50622-0.82353-1.83336-0.48000.h5
# 34/34 [==============================] - 226s 7s/step - loss: 0.5062 - categorical_accuracy: 0.8235 - val_loss: 1.8334 - val_categorical_accuracy: 0.4800 - lr: 8.0000e-06
# Epoch 17/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4645 - categorical_accuracy: 0.8198
# Epoch 00017: saving model to model_init_2024-09-0207_47_24.753026/model-00017-0.46448-0.81976-1.44867-0.54000.h5
# 34/34 [==============================] - 223s 7s/step - loss: 0.4645 - categorical_accuracy: 0.8198 - val_loss: 1.4487 - val_categorical_accuracy: 0.5400 - lr: 8.0000e-06
# Epoch 18/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4741 - categorical_accuracy: 0.8122
# Epoch 00018: saving model to model_init_2024-09-0207_47_24.753026/model-00018-0.47405-0.81222-1.21298-0.59000.h5
# 34/34 [==============================] - 223s 7s/step - loss: 0.4741 - categorical_accuracy: 0.8122 - val_loss: 1.2130 - val_categorical_accuracy: 0.5900 - lr: 8.0000e-06
# Epoch 19/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5187 - categorical_accuracy: 0.7979
# Epoch 00019: saving model to model_init_2024-09-0207_47_24.753026/model-00019-0.51868-0.79789-0.99908-0.65000.h5
# 34/34 [==============================] - 223s 7s/step - loss: 0.5187 - categorical_accuracy: 0.7979 - val_loss: 0.9991 - val_categorical_accuracy: 0.6500 - lr: 8.0000e-06
# Epoch 20/20
# 30/34 [=========================>....] - ETA: 24s - loss: 0.5113 - categorical_accuracy: 0.8083

# %%
plot(history_model9)

# %%
As we see more cases of overfitting, and the val accuracy also is not great

# %% [markdown]
# ## Model 6 - Let us bring in Transfer Learning with GRU !! :)

# %%
# importing the MobileNet model due to it's lightweight architecture and high speed performance as compared 
# to other heavy-duty models like VGG16, Alexnet, InceptionV3 etc. Also, we are now also running on low disk space 
# in the nimblebox.ai platform. 

from keras.applications import mobilenet

# %%
mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)

class RNNCNN_TL(ModelBuilderMoreAugmentation):
    
    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):
        
        model = Sequential()
        model.add(TimeDistributed(mobilenet_transfer,input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        
        
        for layer in model.layers:
            layer.trainable = False
        
        
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        model.add(TimeDistributed(Flatten()))

        model.add(LSTM(lstm_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        
        
        optimiser = Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
rnn_cnn_tl=RNNCNN_TL()
rnn_cnn_tl.initialize_path(project_folder)
rnn_cnn_tl.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn_tl.initialize_hyperparams(frames_to_sample=16,batch_size=5,num_epochs=20)
rnn_cnn_tl_model=rnn_cnn_tl.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn_tl_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_32 (TimeDi  (None, 16, 3, 3, 1024)   3228864
#  stributed)
#
#  time_distributed_33 (TimeDi  (None, 16, 3, 3, 1024)   4096
#  stributed)
#
#  time_distributed_34 (TimeDi  (None, 16, 1, 1, 1024)   0
#  stributed)
#
#  time_distributed_35 (TimeDi  (None, 16, 1024)         0
#  stributed)
#
#  lstm_2 (LSTM)               (None, 128)               590336
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_13 (Dense)            (None, 128)               16512
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_14 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 3,840,453
# Trainable params: 609,541
# Non-trainable params: 3,230,912
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn_tl_model.count_params())
history_model6=rnn_cnn_tl.train_model(rnn_cnn_tl_model,augment_data=True)
# Out:
# Total Params: 3840453
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 133/133 [==============================] - ETA: 0s - loss: 1.3488 - categorical_accuracy: 0.4216
# Epoch 00001: saving model to model_init_2024-09-0120_27_07.484280/model-00001-1.34879-0.42157-1.12159-0.59000.h5
# 133/133 [==============================] - 166s 1s/step - loss: 1.3488 - categorical_accuracy: 0.4216 - val_loss: 1.1216 - val_categorical_accuracy: 0.5900 - lr: 0.0010
# Epoch 2/20
# 133/133 [==============================] - ETA: 0s - loss: 0.8608 - categorical_accuracy: 0.6599
# Epoch 00002: saving model to model_init_2024-09-0120_27_07.484280/model-00002-0.86084-0.65988-0.67949-0.72000.h5
# 133/133 [==============================] - 152s 1s/step - loss: 0.8608 - categorical_accuracy: 0.6599 - val_loss: 0.6795 - val_categorical_accuracy: 0.7200 - lr: 0.0010
# Epoch 3/20
# 133/133 [==============================] - ETA: 0s - loss: 0.6604 - categorical_accuracy: 0.7511
# Epoch 00003: saving model to model_init_2024-09-0120_27_07.484280/model-00003-0.66040-0.75113-0.58810-0.77000.h5
# 133/133 [==============================] - 152s 1s/step - loss: 0.6604 - categorical_accuracy: 0.7511 - val_loss: 0.5881 - val_categorical_accuracy: 0.7700 - lr: 0.0010
# Epoch 4/20
# 133/133 [==============================] - ETA: 0s - loss: 0.5416 - categorical_accuracy: 0.7956
# Epoch 00004: saving model to model_init_2024-09-0120_27_07.484280/model-00004-0.54161-0.79563-0.68221-0.70000.h5
# 133/133 [==============================] - 152s 1s/step - loss: 0.5416 - categorical_accuracy: 0.7956 - val_loss: 0.6822 - val_categorical_accuracy: 0.7000 - lr: 0.0010
# Epoch 5/20
# 133/133 [==============================] - ETA: 0s - loss: 0.3689 - categorical_accuracy: 0.8673
# Epoch 00005: saving model to model_init_2024-09-0120_27_07.484280/model-00005-0.36893-0.86727-0.61141-0.76000.h5
# 133/133 [==============================] - 151s 1s/step - loss: 0.3689 - categorical_accuracy: 0.8673 - val_loss: 0.6114 - val_categorical_accuracy: 0.7600 - lr: 0.0010
# Epoch 6/20
# 133/133 [==============================] - ETA: 0s - loss: 0.2828 - categorical_accuracy: 0.8944
# Epoch 00006: saving model to model_init_2024-09-0120_27_07.484280/model-00006-0.28278-0.89442-0.63244-0.74000.h5
# 133/133 [==============================] - 149s 1s/step - loss: 0.2828 - categorical_accuracy: 0.8944 - val_loss: 0.6324 - val_categorical_accuracy: 0.7400 - lr: 0.0010
# Epoch 7/20
# 133/133 [==============================] - ETA: 0s - loss: 0.2830 - categorical_accuracy: 0.9080
# Epoch 00007: saving model to model_init_2024-09-0120_27_07.484280/model-00007-0.28305-0.90799-0.64172-0.73000.h5
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 133/133 [==============================] - 152s 1s/step - loss: 0.2830 - categorical_accuracy: 0.9080 - val_loss: 0.6417 - val_categorical_accuracy: 0.7300 - lr: 0.0010
# Epoch 8/20
# 133/133 [==============================] - ETA: 0s - loss: 0.1921 - categorical_accuracy: 0.9306
# Epoch 00008: saving model to model_init_2024-09-0120_27_07.484280/model-00008-0.19211-0.93062-0.51576-0.79000.h5
# 133/133 [==============================] - 153s 1s/step - loss: 0.1921 - categorical_accuracy: 0.9306 - val_loss: 0.5158 - val_categorical_accuracy: 0.7900 - lr: 2.0000e-04
# Epoch 9/20
# 133/133 [==============================] - ETA: 0s - loss: 0.1516 - categorical_accuracy: 0.9465
# Epoch 00009: saving model to model_init_2024-09-0120_27_07.484280/model-00009-0.15156-0.94646-0.73455-0.71000.h5
# 133/133 [==============================] - 148s 1s/step - loss: 0.1516 - categorical_accuracy: 0.9465 - val_loss: 0.7345 - val_categorical_accuracy: 0.7100 - lr: 2.0000e-04
# Epoch 10/20
# 133/133 [==============================] - ETA: 0s - loss: 0.1281 - categorical_accuracy: 0.9600
# Epoch 00010: saving model to model_init_2024-09-0120_27_07.484280/model-00010-0.12815-0.96003-0.65158-0.80000.h5
# 133/133 [==============================] - 150s 1s/step - loss: 0.1281 - categorical_accuracy: 0.9600 - val_loss: 0.6516 - val_categorical_accuracy: 0.8000 - lr: 2.0000e-04
# Epoch 11/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0942 - categorical_accuracy: 0.9721
# Epoch 00011: saving model to model_init_2024-09-0120_27_07.484280/model-00011-0.09424-0.97210-0.54980-0.80000.h5
# 133/133 [==============================] - 147s 1s/step - loss: 0.0942 - categorical_accuracy: 0.9721 - val_loss: 0.5498 - val_categorical_accuracy: 0.8000 - lr: 2.0000e-04
# Epoch 12/20
# 133/133 [==============================] - ETA: 0s - loss: 0.1039 - categorical_accuracy: 0.9691
# Epoch 00012: saving model to model_init_2024-09-0120_27_07.484280/model-00012-0.10388-0.96908-0.60577-0.81000.h5
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 133/133 [==============================] - 151s 1s/step - loss: 0.1039 - categorical_accuracy: 0.9691 - val_loss: 0.6058 - val_categorical_accuracy: 0.8100 - lr: 2.0000e-04
# Epoch 13/20
# 133/133 [==============================] - ETA: 0s - loss: 0.1099 - categorical_accuracy: 0.9646
# Epoch 00013: saving model to model_init_2024-09-0120_27_07.484280/model-00013-0.10993-0.96456-0.67919-0.75000.h5
# 133/133 [==============================] - 151s 1s/step - loss: 0.1099 - categorical_accuracy: 0.9646 - val_loss: 0.6792 - val_categorical_accuracy: 0.7500 - lr: 4.0000e-05
# Epoch 14/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0969 - categorical_accuracy: 0.9698
# Epoch 00014: saving model to model_init_2024-09-0120_27_07.484280/model-00014-0.09692-0.96983-0.77404-0.72000.h5
# 133/133 [==============================] - 149s 1s/step - loss: 0.0969 - categorical_accuracy: 0.9698 - val_loss: 0.7740 - val_categorical_accuracy: 0.7200 - lr: 4.0000e-05
# Epoch 15/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0877 - categorical_accuracy: 0.9721
# Epoch 00015: saving model to model_init_2024-09-0120_27_07.484280/model-00015-0.08767-0.97210-0.53322-0.78000.h5
# 133/133 [==============================] - 152s 1s/step - loss: 0.0877 - categorical_accuracy: 0.9721 - val_loss: 0.5332 - val_categorical_accuracy: 0.7800 - lr: 4.0000e-05
# Epoch 16/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0799 - categorical_accuracy: 0.9729
# Epoch 00016: saving model to model_init_2024-09-0120_27_07.484280/model-00016-0.07989-0.97285-0.68837-0.76000.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 133/133 [==============================] - 151s 1s/step - loss: 0.0799 - categorical_accuracy: 0.9729 - val_loss: 0.6884 - val_categorical_accuracy: 0.7600 - lr: 4.0000e-05
# Epoch 17/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0769 - categorical_accuracy: 0.9721
# Epoch 00017: saving model to model_init_2024-09-0120_27_07.484280/model-00017-0.07690-0.97210-0.65817-0.77000.h5
# 133/133 [==============================] - 154s 1s/step - loss: 0.0769 - categorical_accuracy: 0.9721 - val_loss: 0.6582 - val_categorical_accuracy: 0.7700 - lr: 8.0000e-06
# Epoch 18/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0717 - categorical_accuracy: 0.9774
# Epoch 00018: saving model to model_init_2024-09-0120_27_07.484280/model-00018-0.07167-0.97738-0.65088-0.75000.h5
# 133/133 [==============================] - 152s 1s/step - loss: 0.0717 - categorical_accuracy: 0.9774 - val_loss: 0.6509 - val_categorical_accuracy: 0.7500 - lr: 8.0000e-06
# Epoch 19/20
# 133/133 [==============================] - ETA: 0s - loss: 0.1070 - categorical_accuracy: 0.9646
# Epoch 00019: saving model to model_init_2024-09-0120_27_07.484280/model-00019-0.10697-0.96456-0.59464-0.78000.h5
# 133/133 [==============================] - 151s 1s/step - loss: 0.1070 - categorical_accuracy: 0.9646 - val_loss: 0.5946 - val_categorical_accuracy: 0.7800 - lr: 8.0000e-06
# Epoch 20/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0771 - categorical_accuracy: 0.9759

# %%
plot(history_model6)

# %% [markdown]
# ##### We are not training the mobilenet weights and we see validation accuracy is very poor. Let's train them as well and observe if there is performance improvement

# %% [markdown]
# ## Model 7 - Transfer Learning with GRU and training all weights

# %%
from keras.applications import mobilenet

mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)

class RNNCNN_TL2(ModelBuilderMoreAugmentation):
    
    def define_model(self,gru_cells=64,dense_neurons=64,dropout=0.25):
        
        model = Sequential()
        model.add(TimeDistributed(mobilenet_transfer,input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
 
        
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        model.add(TimeDistributed(Flatten()))

        model.add(GRU(gru_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        
        
        optimiser = Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
rnn_cnn_tl2=RNNCNN_TL2()
rnn_cnn_tl2.initialize_path(project_folder)
rnn_cnn_tl2.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn_tl2.initialize_hyperparams(frames_to_sample=16,batch_size=5,num_epochs=20)
rnn_cnn_tl2_model=rnn_cnn_tl2.define_model(gru_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn_tl2_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 16, 3, 3, 1024)   3228864
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 16, 3, 3, 1024)   4096
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 16, 1, 1, 1024)   0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 16, 1024)         0
#  tributed)
#
#  gru (GRU)                   (None, 128)               443136
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 3,693,253
# Trainable params: 3,669,317
# Non-trainable params: 23,936
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn_tl2_model.count_params())
history_model7=rnn_cnn_tl2.train_model(rnn_cnn_tl2_model,augment_data=True)
# Out:
# Total Params: 3693253
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 2024-09-02 02:11:27.739547: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 133/133 [==============================] - ETA: 0s - loss: 1.2801 - categorical_accuracy: 0.4668
# Epoch 00001: saving model to model_init_2024-09-0202_11_20.830010/model-00001-1.28012-0.46682-0.87003-0.68000.h5
# 133/133 [==============================] - 180s 1s/step - loss: 1.2801 - categorical_accuracy: 0.4668 - val_loss: 0.8700 - val_categorical_accuracy: 0.6800 - lr: 0.0010
# Epoch 2/20
# 133/133 [==============================] - ETA: 0s - loss: 0.6754 - categorical_accuracy: 0.7338
# Epoch 00002: saving model to model_init_2024-09-0202_11_20.830010/model-00002-0.67538-0.73379-0.34976-0.89000.h5
# 133/133 [==============================] - 162s 1s/step - loss: 0.6754 - categorical_accuracy: 0.7338 - val_loss: 0.3498 - val_categorical_accuracy: 0.8900 - lr: 0.0010
# Epoch 3/20
# 133/133 [==============================] - ETA: 0s - loss: 0.4403 - categorical_accuracy: 0.8416
# Epoch 00003: saving model to model_init_2024-09-0202_11_20.830010/model-00003-0.44028-0.84163-0.30815-0.91000.h5
# 133/133 [==============================] - 159s 1s/step - loss: 0.4403 - categorical_accuracy: 0.8416 - val_loss: 0.3081 - val_categorical_accuracy: 0.9100 - lr: 0.0010
# Epoch 4/20
# 133/133 [==============================] - ETA: 0s - loss: 0.3804 - categorical_accuracy: 0.8612
# Epoch 00004: saving model to model_init_2024-09-0202_11_20.830010/model-00004-0.38035-0.86124-0.32541-0.87000.h5
# 133/133 [==============================] - 158s 1s/step - loss: 0.3804 - categorical_accuracy: 0.8612 - val_loss: 0.3254 - val_categorical_accuracy: 0.8700 - lr: 0.0010
# Epoch 5/20
# 133/133 [==============================] - ETA: 0s - loss: 0.2748 - categorical_accuracy: 0.9050
# Epoch 00005: saving model to model_init_2024-09-0202_11_20.830010/model-00005-0.27483-0.90498-0.40877-0.83000.h5
# 133/133 [==============================] - 158s 1s/step - loss: 0.2748 - categorical_accuracy: 0.9050 - val_loss: 0.4088 - val_categorical_accuracy: 0.8300 - lr: 0.0010
# Epoch 6/20
# 133/133 [==============================] - ETA: 0s - loss: 0.2724 - categorical_accuracy: 0.9140
# Epoch 00006: saving model to model_init_2024-09-0202_11_20.830010/model-00006-0.27241-0.91403-0.49868-0.79000.h5
# 133/133 [==============================] - 162s 1s/step - loss: 0.2724 - categorical_accuracy: 0.9140 - val_loss: 0.4987 - val_categorical_accuracy: 0.7900 - lr: 0.0010
# Epoch 7/20
# 133/133 [==============================] - ETA: 0s - loss: 0.3174 - categorical_accuracy: 0.8974
# Epoch 00007: saving model to model_init_2024-09-0202_11_20.830010/model-00007-0.31741-0.89744-0.71433-0.80000.h5
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 133/133 [==============================] - 157s 1s/step - loss: 0.3174 - categorical_accuracy: 0.8974 - val_loss: 0.7143 - val_categorical_accuracy: 0.8000 - lr: 0.0010
# Epoch 8/20
# 133/133 [==============================] - ETA: 0s - loss: 0.2634 - categorical_accuracy: 0.9140
# Epoch 00008: saving model to model_init_2024-09-0202_11_20.830010/model-00008-0.26336-0.91403-0.08915-1.00000.h5
# 133/133 [==============================] - 157s 1s/step - loss: 0.2634 - categorical_accuracy: 0.9140 - val_loss: 0.0891 - val_categorical_accuracy: 1.0000 - lr: 2.0000e-04
# Epoch 9/20
# 133/133 [==============================] - ETA: 0s - loss: 0.1105 - categorical_accuracy: 0.9653
# Epoch 00009: saving model to model_init_2024-09-0202_11_20.830010/model-00009-0.11055-0.96531-0.04551-0.99000.h5
# 133/133 [==============================] - 158s 1s/step - loss: 0.1105 - categorical_accuracy: 0.9653 - val_loss: 0.0455 - val_categorical_accuracy: 0.9900 - lr: 2.0000e-04
# Epoch 10/20
# 133/133 [==============================] - ETA: 0s - loss: 0.1118 - categorical_accuracy: 0.9683
# Epoch 00010: saving model to model_init_2024-09-0202_11_20.830010/model-00010-0.11179-0.96833-0.10277-0.97000.h5
# 133/133 [==============================] - 162s 1s/step - loss: 0.1118 - categorical_accuracy: 0.9683 - val_loss: 0.1028 - val_categorical_accuracy: 0.9700 - lr: 2.0000e-04
# Epoch 11/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0786 - categorical_accuracy: 0.9811
# Epoch 00011: saving model to model_init_2024-09-0202_11_20.830010/model-00011-0.07862-0.98115-0.03146-0.99000.h5
# 133/133 [==============================] - 158s 1s/step - loss: 0.0786 - categorical_accuracy: 0.9811 - val_loss: 0.0315 - val_categorical_accuracy: 0.9900 - lr: 2.0000e-04
# Epoch 12/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0603 - categorical_accuracy: 0.9819
# Epoch 00012: saving model to model_init_2024-09-0202_11_20.830010/model-00012-0.06031-0.98190-0.02747-1.00000.h5
# 133/133 [==============================] - 152s 1s/step - loss: 0.0603 - categorical_accuracy: 0.9819 - val_loss: 0.0275 - val_categorical_accuracy: 1.0000 - lr: 2.0000e-04
# Epoch 13/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0517 - categorical_accuracy: 0.9819
# Epoch 00013: saving model to model_init_2024-09-0202_11_20.830010/model-00013-0.05175-0.98190-0.13647-0.97000.h5
# 133/133 [==============================] - 156s 1s/step - loss: 0.0517 - categorical_accuracy: 0.9819 - val_loss: 0.1365 - val_categorical_accuracy: 0.9700 - lr: 2.0000e-04
# Epoch 14/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0306 - categorical_accuracy: 0.9917
# Epoch 00014: saving model to model_init_2024-09-0202_11_20.830010/model-00014-0.03065-0.99170-0.07158-0.98000.h5
# 133/133 [==============================] - 152s 1s/step - loss: 0.0306 - categorical_accuracy: 0.9917 - val_loss: 0.0716 - val_categorical_accuracy: 0.9800 - lr: 2.0000e-04
# Epoch 15/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0378 - categorical_accuracy: 0.9879
# Epoch 00015: saving model to model_init_2024-09-0202_11_20.830010/model-00015-0.03783-0.98793-0.08323-0.96000.h5
# 133/133 [==============================] - 166s 1s/step - loss: 0.0378 - categorical_accuracy: 0.9879 - val_loss: 0.0832 - val_categorical_accuracy: 0.9600 - lr: 2.0000e-04
# Epoch 16/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0193 - categorical_accuracy: 0.9962
# Epoch 00016: saving model to model_init_2024-09-0202_11_20.830010/model-00016-0.01925-0.99623-0.05811-0.98000.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 133/133 [==============================] - 152s 1s/step - loss: 0.0193 - categorical_accuracy: 0.9962 - val_loss: 0.0581 - val_categorical_accuracy: 0.9800 - lr: 2.0000e-04
# Epoch 17/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0198 - categorical_accuracy: 0.9940
# Epoch 00017: saving model to model_init_2024-09-0202_11_20.830010/model-00017-0.01979-0.99397-0.06054-0.98000.h5
# 133/133 [==============================] - 160s 1s/step - loss: 0.0198 - categorical_accuracy: 0.9940 - val_loss: 0.0605 - val_categorical_accuracy: 0.9800 - lr: 4.0000e-05
# Epoch 18/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0202 - categorical_accuracy: 0.9947
# Epoch 00018: saving model to model_init_2024-09-0202_11_20.830010/model-00018-0.02022-0.99472-0.07724-0.98000.h5
# 133/133 [==============================] - 164s 1s/step - loss: 0.0202 - categorical_accuracy: 0.9947 - val_loss: 0.0772 - val_categorical_accuracy: 0.9800 - lr: 4.0000e-05
# Epoch 19/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0147 - categorical_accuracy: 0.9947
# Epoch 00019: saving model to model_init_2024-09-0202_11_20.830010/model-00019-0.01472-0.99472-0.06324-0.98000.h5
# 133/133 [==============================] - 159s 1s/step - loss: 0.0147 - categorical_accuracy: 0.9947 - val_loss: 0.0632 - val_categorical_accuracy: 0.9800 - lr: 4.0000e-05
# Epoch 20/20
# 102/133 [======================>.......] - ETA: 34s - loss: 0.0162 - categorical_accuracy: 0.9951

# %%
plot(history_model7)

# %% [markdown]
# ### This is one of the best results till date! 99.47% Training accuracy and 98% validation accuracy

# %% [markdown]
# ## After doing all the experiments, I finalized Model 7 - GRU with Transfer learning MobileNite with all weights trained, which performed well.
# __Reason:__
#
# __- (Training Accuracy : 99.47%, Validation Accuracy : 98%%)__
#
# __- Number of trainable Parameters 3,669,317__
#
# __- Learning rate gradually decreacing after 8th Epoch__
#
#
# __The best weights of GRU-CNNRNN transfer learning model: model-00020-0.01945-0.99472-0.05497-0.98000.h5 (42.4 MB). we considered this weight for model testing, Let's have look at the performance below__
# -**Training completed in about 53 minutes**

# %% [markdown]
# # Loading model and Testing

# %%
import time
from keras.models import load_model
model = load_model('model_init_2021-01-1223_50_50.411328/model-00020-0.01945-0.99472-0.05497-0.98000.h5')

# %%
test_generator=RNNCNN_TL2()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn_tl2.initialize_hyperparams(frames_to_sample=16,batch_size=5,num_epochs=20)
rnn_cnn_tl2_model=rnn_cnn_tl2.define_model(gru_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn_tl2_model.summ

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=False)
batch_data, batch_labels=next(g)

# %%
print(np.argmax(model.predict(batch_data[:,:,:,:,:]),axis=1))
